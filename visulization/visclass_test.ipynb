# %%
from visclass import vis
import numpy as np

# %%
X = np.array([[6, 7, 8, 9, 10, 11, 12],[10, 11, 12, 13, 14, 15, 16],[11, 12, 13, 14, 15, 16,17]])
Y = np.array([[4,2,3,1,5,6,2],[0,2,3,1,5,1,5],[0, 10, 5, 17, 14, 15, 11]])

# %%
vis = vis()

# %%
vis.make_vis(X,Y, alpha=0.2, n=100, scatter=False,fig_size=(20,10), xlabel='asdf', ylabel='sdfg', title='qwer')

# %%
vis.make_subplots(X,Y,alpha=0.2,)
